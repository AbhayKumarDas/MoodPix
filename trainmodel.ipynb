# %%
# !pip install keras-preprocessing
# Out:
# Collecting keras-preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from keras-preprocessing) (1.26.4)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from keras-preprocessing) (1.16.0)
# Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: keras-preprocessing
# Successfully installed keras-preprocessing-1.1.2

# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np
import keras
# Out:
# 2024-07-19 14:13:09.057947: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-19 14:13:09.058052: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-19 14:13:09.205332: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
TRAIN_DIR = '/kaggle/input/face-expression-recognition-dataset/images/train'
TEST_DIR = '/kaggle/input/face-expression-recognition-dataset/images/validation'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths,labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# surprise completed
# fear completed
# angry completed
# neutral completed
# sad completed
# disgust completed
# happy completed

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# surprise completed
# fear completed
# angry completed
# neutral completed
# sad completed
# disgust completed
# happy completed

# %%
from tqdm.notebook import tqdm

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image,grayscale =  True )
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/keras_preprocessing/image/utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
model = Sequential()
# convolutional layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output layer
model.add(Dense(7, activation='softmax'))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'] )

# %%
model.fit(x= x_train,y = y_train, batch_size = 128, epochs = 100, validation_data = (x_test,y_test))
# Out:
# Epoch 1/100
#   6/226 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.1555 - loss: 1.9291
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721398619.382115     118 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 34s 78ms/step - accuracy: 0.2351 - loss: 1.8370 - val_accuracy: 0.2622 - val_loss: 1.8214
# Epoch 2/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.2325 - loss: 1.8246 - val_accuracy: 0.2646 - val_loss: 1.8058
# Epoch 3/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.2553 - loss: 1.7911 - val_accuracy: 0.2975 - val_loss: 1.7148
# Epoch 4/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.2965 - loss: 1.7220 - val_accuracy: 0.3375 - val_loss: 1.6554
# Epoch 5/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.3272 - loss: 1.6774 - val_accuracy: 0.3990 - val_loss: 1.5264
# Epoch 6/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.3716 - loss: 1.5895 - val_accuracy: 0.4367 - val_loss: 1.4411
# Epoch 7/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.4035 - loss: 1.5306 - val_accuracy: 0.4595 - val_loss: 1.4069
# Epoch 8/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.4261 - loss: 1.4879 - val_accuracy: 0.4771 - val_loss: 1.3701
# Epoch 9/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.4479 - loss: 1.4395 - val_accuracy: 0.4858 - val_loss: 1.3382
# Epoch 10/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.4544 - loss: 1.4138 - val_accuracy: 0.4928 - val_loss: 1.3050
# Epoch 11/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.4704 - loss: 1.3877 - val_accuracy: 0.5129 - val_loss: 1.2791
# Epoch 12/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.4724 - loss: 1.3727 - val_accuracy: 0.5242 - val_loss: 1.2517
# Epoch 13/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.4868 - loss: 1.3381 - val_accuracy: 0.5359 - val_loss: 1.2244
# Epoch 14/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.4930 - loss: 1.3197 - val_accuracy: 0.5381 - val_loss: 1.2187
# Epoch 15/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5010 - loss: 1.3130 - val_accuracy: 0.5416 - val_loss: 1.1984
# Epoch 16/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5068 - loss: 1.2937 - val_accuracy: 0.5450 - val_loss: 1.1889
# Epoch 17/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5119 - loss: 1.2770 - val_accuracy: 0.5562 - val_loss: 1.1809
# Epoch 18/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5162 - loss: 1.2739 - val_accuracy: 0.5502 - val_loss: 1.1872
# Epoch 19/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5193 - loss: 1.2666 - val_accuracy: 0.5590 - val_loss: 1.1627
# Epoch 20/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5226 - loss: 1.2535 - val_accuracy: 0.5662 - val_loss: 1.1499
# Epoch 21/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5339 - loss: 1.2360 - val_accuracy: 0.5613 - val_loss: 1.1569
# Epoch 22/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5264 - loss: 1.2425 - val_accuracy: 0.5735 - val_loss: 1.1281
# Epoch 23/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5254 - loss: 1.2421 - val_accuracy: 0.5725 - val_loss: 1.1338
# Epoch 24/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5460 - loss: 1.2094 - val_accuracy: 0.5802 - val_loss: 1.1139
# Epoch 25/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5397 - loss: 1.2146 - val_accuracy: 0.5780 - val_loss: 1.1189
# Epoch 26/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5464 - loss: 1.1982 - val_accuracy: 0.5719 - val_loss: 1.1318
# Epoch 27/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5543 - loss: 1.1866 - val_accuracy: 0.5682 - val_loss: 1.1431
# Epoch 28/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5520 - loss: 1.1850 - val_accuracy: 0.5904 - val_loss: 1.1016
# Epoch 29/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5514 - loss: 1.1750 - val_accuracy: 0.5863 - val_loss: 1.0950
# Epoch 30/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5611 - loss: 1.1670 - val_accuracy: 0.5889 - val_loss: 1.0915
# Epoch 31/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5533 - loss: 1.1698 - val_accuracy: 0.5951 - val_loss: 1.0910
# Epoch 32/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5689 - loss: 1.1486 - val_accuracy: 0.5887 - val_loss: 1.0921
# Epoch 33/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5673 - loss: 1.1545 - val_accuracy: 0.5938 - val_loss: 1.0953
# Epoch 34/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5671 - loss: 1.1516 - val_accuracy: 0.5950 - val_loss: 1.0870
# Epoch 35/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5733 - loss: 1.1329 - val_accuracy: 0.6009 - val_loss: 1.0755
# Epoch 36/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5754 - loss: 1.1180 - val_accuracy: 0.5969 - val_loss: 1.0784
# Epoch 37/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5830 - loss: 1.1148 - val_accuracy: 0.5944 - val_loss: 1.0807
# Epoch 38/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5742 - loss: 1.1201 - val_accuracy: 0.6057 - val_loss: 1.0647
# Epoch 39/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5822 - loss: 1.1052 - val_accuracy: 0.5995 - val_loss: 1.0666
# Epoch 40/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5791 - loss: 1.1074 - val_accuracy: 0.5991 - val_loss: 1.0694
# Epoch 41/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5877 - loss: 1.0968 - val_accuracy: 0.6052 - val_loss: 1.0582
# Epoch 42/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5850 - loss: 1.0912 - val_accuracy: 0.6006 - val_loss: 1.0780
# Epoch 43/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5892 - loss: 1.0929 - val_accuracy: 0.6073 - val_loss: 1.0635
# Epoch 44/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5891 - loss: 1.0955 - val_accuracy: 0.6091 - val_loss: 1.0508
# Epoch 45/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.5943 - loss: 1.0805 - val_accuracy: 0.6093 - val_loss: 1.0483
# Epoch 46/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.5968 - loss: 1.0682 - val_accuracy: 0.6081 - val_loss: 1.0526
# Epoch 47/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.5961 - loss: 1.0772 - val_accuracy: 0.6108 - val_loss: 1.0493
# Epoch 48/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6040 - loss: 1.0516 - val_accuracy: 0.6146 - val_loss: 1.0469
# Epoch 49/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6044 - loss: 1.0602 - val_accuracy: 0.6152 - val_loss: 1.0377
# Epoch 50/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6086 - loss: 1.0406 - val_accuracy: 0.6131 - val_loss: 1.0401
# Epoch 51/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6061 - loss: 1.0486 - val_accuracy: 0.6142 - val_loss: 1.0409
# Epoch 52/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.6130 - loss: 1.0291 - val_accuracy: 0.6084 - val_loss: 1.0513
# Epoch 53/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6142 - loss: 1.0300 - val_accuracy: 0.6054 - val_loss: 1.0536
# Epoch 54/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.6091 - loss: 1.0388 - val_accuracy: 0.6080 - val_loss: 1.0514
# Epoch 55/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6141 - loss: 1.0319 - val_accuracy: 0.6104 - val_loss: 1.0463
# Epoch 56/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6215 - loss: 1.0114 - val_accuracy: 0.6125 - val_loss: 1.0300
# Epoch 57/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6228 - loss: 1.0038 - val_accuracy: 0.6080 - val_loss: 1.0576
# Epoch 58/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6285 - loss: 1.0048 - val_accuracy: 0.6135 - val_loss: 1.0429
# Epoch 59/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.6227 - loss: 1.0008 - val_accuracy: 0.6124 - val_loss: 1.0448
# Epoch 60/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6260 - loss: 0.9960 - val_accuracy: 0.6192 - val_loss: 1.0285
# Epoch 61/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6220 - loss: 1.0099 - val_accuracy: 0.6162 - val_loss: 1.0307
# Epoch 62/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6381 - loss: 0.9747 - val_accuracy: 0.6206 - val_loss: 1.0322
# Epoch 63/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6221 - loss: 1.0079 - val_accuracy: 0.6169 - val_loss: 1.0291
# Epoch 64/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6313 - loss: 0.9783 - val_accuracy: 0.6183 - val_loss: 1.0292
# Epoch 65/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6340 - loss: 0.9713 - val_accuracy: 0.6217 - val_loss: 1.0224
# Epoch 66/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6387 - loss: 0.9693 - val_accuracy: 0.6168 - val_loss: 1.0320
# Epoch 67/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6369 - loss: 0.9672 - val_accuracy: 0.6162 - val_loss: 1.0249
# Epoch 68/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6398 - loss: 0.9709 - val_accuracy: 0.6220 - val_loss: 1.0180
# Epoch 69/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6409 - loss: 0.9630 - val_accuracy: 0.6162 - val_loss: 1.0262
# Epoch 70/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6391 - loss: 0.9725 - val_accuracy: 0.6202 - val_loss: 1.0227
# Epoch 71/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.6476 - loss: 0.9495 - val_accuracy: 0.6251 - val_loss: 1.0158
# Epoch 72/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6429 - loss: 0.9526 - val_accuracy: 0.6230 - val_loss: 1.0239
# Epoch 73/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6421 - loss: 0.9550 - val_accuracy: 0.6185 - val_loss: 1.0247
# Epoch 74/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6539 - loss: 0.9266 - val_accuracy: 0.6245 - val_loss: 1.0148
# Epoch 75/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.6538 - loss: 0.9315 - val_accuracy: 0.6275 - val_loss: 1.0104
# Epoch 76/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6480 - loss: 0.9385 - val_accuracy: 0.6187 - val_loss: 1.0227
# Epoch 77/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6482 - loss: 0.9403 - val_accuracy: 0.6243 - val_loss: 1.0120
# Epoch 78/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6569 - loss: 0.9190 - val_accuracy: 0.6202 - val_loss: 1.0356
# Epoch 79/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6568 - loss: 0.9227 - val_accuracy: 0.6210 - val_loss: 1.0103
# Epoch 80/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6635 - loss: 0.9159 - val_accuracy: 0.6203 - val_loss: 1.0112
# Epoch 81/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6587 - loss: 0.9245 - val_accuracy: 0.6248 - val_loss: 1.0116
# Epoch 82/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.6638 - loss: 0.9032 - val_accuracy: 0.6206 - val_loss: 1.0259
# Epoch 83/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6644 - loss: 0.9124 - val_accuracy: 0.6240 - val_loss: 1.0134
# Epoch 84/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6589 - loss: 0.9038 - val_accuracy: 0.6274 - val_loss: 1.0108
# Epoch 85/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6665 - loss: 0.8887 - val_accuracy: 0.6255 - val_loss: 1.0236
# Epoch 86/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6643 - loss: 0.8953 - val_accuracy: 0.6294 - val_loss: 1.0107
# Epoch 87/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6710 - loss: 0.8898 - val_accuracy: 0.6278 - val_loss: 1.0092
# Epoch 88/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6822 - loss: 0.8696 - val_accuracy: 0.6248 - val_loss: 1.0217
# Epoch 89/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6690 - loss: 0.8810 - val_accuracy: 0.6255 - val_loss: 1.0094
# Epoch 90/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6703 - loss: 0.8878 - val_accuracy: 0.6258 - val_loss: 1.0126
# Epoch 91/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6752 - loss: 0.8789 - val_accuracy: 0.6254 - val_loss: 1.0124
# Epoch 92/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6768 - loss: 0.8775 - val_accuracy: 0.6245 - val_loss: 1.0255
# Epoch 93/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.6772 - loss: 0.8590 - val_accuracy: 0.6282 - val_loss: 1.0146
# Epoch 94/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6805 - loss: 0.8690 - val_accuracy: 0.6294 - val_loss: 1.0058
# Epoch 95/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6794 - loss: 0.8630 - val_accuracy: 0.6265 - val_loss: 1.0238
# Epoch 96/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6852 - loss: 0.8570 - val_accuracy: 0.6308 - val_loss: 1.0182
# Epoch 97/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6874 - loss: 0.8389 - val_accuracy: 0.6269 - val_loss: 1.0183
# Epoch 98/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6827 - loss: 0.8558 - val_accuracy: 0.6298 - val_loss: 1.0063
# Epoch 99/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6872 - loss: 0.8481 - val_accuracy: 0.6322 - val_loss: 1.0098
# Epoch 100/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6882 - loss: 0.8503 - val_accuracy: 0.6282 - val_loss: 1.0025

# %%
model_json = model.to_json()
with open("emotiondetector.json",'w') as json_file:
    json_file.write(model_json)
model.save("emotiondetector.h5")

# %%
import cv2
from keras._tf_keras.keras.models import model_from_json
import numpy as np
# from keras_preprocessing.image import load_img
json_file = open("emotiondetector.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)

model.load_weights("emotiondetector.h5")
haar_file=cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
face_cascade=cv2.CascadeClassifier(haar_file)

def extract_features(image):
    feature = np.array(image)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

webcam=cv2.VideoCapture(0)
labels = {0 : 'angry', 1 : 'disgust', 2 : 'fear', 3 : 'happy', 4 : 'neutral', 5 : 'sad', 6 : 'surprise'}
while True:
    i,im=webcam.read()
    gray=cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    faces=face_cascade.detectMultiScale(im,1.3,5)
    try: 
        for (p,q,r,s) in faces:
            image = gray[q:q+s,p:p+r]
            cv2.rectangle(im,(p,q),(p+r,q+s),(255,0,0),2)
            image = cv2.resize(image,(48,48))
            img = extract_features(image)
            pred = model.predict(img)
            prediction_label = labels[pred.argmax()]
            # print("Predicted Output:", prediction_label)
            # cv2.putText(im,prediction_label)
            cv2.putText(im, '% s' %(prediction_label), (p-10, q-10),cv2.FONT_HERSHEY_COMPLEX_SMALL,2, (0,0,255))
        cv2.imshow("Output",im)
        cv2.waitKey(27)
    except cv2.error:
        pass
# Out:
# [ WARN:0@43.282] global cap_v4l.cpp:999 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@43.283] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[22], line 23
#      21 while True:
#      22     i,im=webcam.read()
# ---> 23     gray=cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
#      24     faces=face_cascade.detectMultiScale(im,1.3,5)
#      25     try:
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
